# %%
from __future__ import print_function
import sys

# This is not required if you've installed pycparser into
# your site-packages/ with setup.py
#
sys.path.extend(['.', '..'])

from pycparser import c_parser, c_ast
from pycparser import parse_file

# %%
ast = parse_file('./pycparser-master/examples/c_files/hash.c', use_cpp=True,
        cpp_path='gcc',
        cpp_args=['-E', r'-Iutils/fake_libc_include']
        )

'''
ast = parse_file('./pycparser-master/examples/c_files/funky.c', use_cpp=True,
        cpp_path='gcc',
        cpp_args=['-E', r'-Iutils/fake_libc_include']
        )
'''

'''
ast = parse_file('./pycparser-master/examples/c_files/year.c', use_cpp=True,
        cpp_path='gcc',
        cpp_args=['-E', r'-Iutils/fake_libc_include']
        )'''
# Out:
# "\nast = parse_file('./pycparser-master/examples/c_files/year.c', use_cpp=True,\n        cpp_path='gcc',\n        cpp_args=['-E', r'-Iutils/fake_libc_include']\n        )"

# %%
def traverse(node):
    # global num_pointers
    global type_pointer
    global tpoint
    global func_pointer
    global fpoint
    #global is_declaration
    global func_call
    global func_decl
    global assignment
    global is_return
    global array_ref
    global num_params
    #print(node)

    
    '''
        pycparser prepoznaje 46 tipova cvorova stabla AST
    
        Potrebno je obici cvorove stabla i obraditi ih na odgovarajuci nacin
    '''
    # child od FileAST moze da bude Decl|FuncDef|Typedef
    
    if isinstance (node, c_ast.ArrayDecl):
        print("ArrayDecl")
        # ArrayDecl[type*, dim*, dim_quals*]
        
        if node.type:
            traverse(node.type)
        if node.dim:
            traverse(node.dim)
        if node.dim_quals:
            traverse(node.dim_quals)
        
    elif isinstance (node, c_ast.ArrayRef):
        print("ArrayRef")
        # ArrayRef[name*, subscript*]
        array_ref = True
        
        if node.name:
            traverse(node.name)
        if node.subscript:
            traverse(node.subscript)
        
    elif isinstance (node, c_ast.Assignment):
        print("Assignment")
        # Assignment[op, lvalue*, rvalue*]
        
        if node.op in operators:
            operators[node.op] += 1
        else:
            operators[node.op] = 1
        
        assignment = True
                        
        if node.lvalue:
            traverse(node.lvalue)
        if node.rvalue:
            traverse(node.rvalue)
                
        
    elif isinstance (node, c_ast.BinaryOp):
        print("Binary op")
        # BinaryOp[op, left*, right*]
        # a = 5
        # a = b = i + 5 - l/3
        
        if node.op in operators:
            operators[node.op] += 1
        else: 
            operators[node.op] = 1
            
        # moraju da postoje left i right, provera je suvisna
        if node.left:
            traverse(node.left)
        if node.right:
            traverse(node.right)
        
        
    elif isinstance (node, c_ast.Break):
        print("Break")
        # Break[]
        
        if "break" in operators:
            operators["break"] += 1
        else:
            operators["break"] = 1          
        
    elif isinstance (node, c_ast.Case):
        print("Case")
        # Case[expr*, stmts**]
        
        if node.expr:
            traverse(node.expr)
        if node.stmts:
            for stmt in node.stmts:
                traverse(stmt)
        
        
    elif isinstance (node, c_ast.Cast):
        print("Cast")
        # Cast[to_type*, expr*] -> (int) l
        
        if node.to_type:
            traverse(node.to_type)
        if node.expr:
            traverse(node.expr)
        
    elif isinstance (node, c_ast.Compound):
        print("Compound")
        # Compound[block_items**]
        # ->  {
        #       ..., ..., 
        #       ...
        #      }
        
        if node.block_items:
            for item in node.block_items:
                traverse(item)

        
    elif isinstance (node, c_ast.CompoundLiteral):
        print("Compound literal")
        # CompoundLiteral[type*, init*]
        
        if node.type:
            traverse(node.type)
        if node.init:
            traverse(node.init)
        
    elif isinstance (node, c_ast.Constant):
        print("Constant")
        # Const[type, value]
        # U ovom slucaju ne treba nista da se radi jer je konstanta karakter 'a' ili broj 5, ...
        return
    elif isinstance (node, c_ast.Continue):
        print("Continue")
        #Continue[]
        
        if "continue" in operators:
            operators["continue"] += 1
        else:
            operators["continue"] = 1
        
    elif isinstance (node, c_ast.Decl):
        print("Decl")
        # Decl[name, quals, storage, funspace, type*, init*, bitsize*]
        
        # name parametar nije znacajan zato sto imena funkcija i promenljivih prilikom deklaracija
        # ne spadaju u operatore tj. operande
        
        # is_declaration += 1
        
        # const, volatile
        quals = node.quals        
        if quals: # if true
            if (len(quals) == 2):
                #print(quals[0]+"   "+quals[1])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                if (quals[1] in operators):
                    operators[quals[1]] += 1
                else:
                    operators[quals[1]] = 1
            else: #(node.quals() == 1):
                #print(quals[0])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                
        # extern, register
        storage = node.storage        
        if storage: # if true
            if (len(storage) == 2):
                #print(storage[0]+"   "+storage[1])
                if (storage[0] in operators):
                    operators[storage[0]] += 1
                else:
                    operators[storage[0]] = 1
                if (storage[1] in operators):
                    operators[storage[1]] += 1
                else:
                    operators[storage[1]] = 1
            else: #(len(storage) == 1):
                #print(storage[0])
                if (storage[0] in operators):
                    operators[storage[0]] += 1
                else:
                    operators[storage[0]] = 1   
        
        # funspec
        funcspec = node.funcspec
        if funcspec:
            print(funcspec[0])
            if (funcspec[0] in operators):
                operators[funcspec[0]] += 1
            else:
                operators[funcspec[0]] = 1  
        
        if node.type:
            traverse(node.type)
        if node.init:
            if '=' in operators:
                operators['='] += 1
            else:
                operators['='] = 1
            traverse(node.init)
        if node.bitsize:
            traverse(node.bitsize)
            
    elif isinstance (node, c_ast.DeclList):
        print("decl list")
        # DeclList[decls**]
        
        if node.decls:
            for decl in node.decls:
                traverse(decl)
        
    elif isinstance (node, c_ast.Default):
        print("default")
        # Default[stmts**]
        
        if node.stmts:
            for stmt in node.stmts:
                traverse(stmt)
        
    elif isinstance (node, c_ast.DoWhile):
        print("do while")
        # DoWhile[cond*, stmt*]
        '''
        do {
           statement(s);
        } while( condition );
        '''
        
        if "do while" in operators:
            operators["do while"] += 1
        else:
            operators["do while"] = 1
        
        if node.cond:
            traverse(node.cond)
        if node.stmt:
            traverse(node.stmt)        
        
    elif isinstance (node, c_ast.EllipsisParam):
        print("ellipsis param")
        # EllipsisParam[]
        # ( ... ) deo u deklaraciji funkcije
        # treba samo zabeleziti zagrade ili ne raditi nista ako se zagrade broje naknadno
        
    elif isinstance (node, c_ast.EmptyStatement):
        print("empty statement")
        # EmptyStatement[]
        # samo ;
        
    elif isinstance (node, c_ast.Enum):
        print("enum")
        # Enum[name, values*]
        # enum week{Mon, Tue, Wed, Thur, Fri, Sat, Sun};
        
        # Enumeration type specifier
        # name: an optional ID
        # values: an EnumeratorList
        
        if "enum" in operators:
            operators["enum"] += 1
        else:
            operators["enum"] = 1
        
        # posto je u pitanju deklaracija ime i vrednosti nas ne zanimaju
        
        if node.values:
            traverse(node.values)        
        
    elif isinstance (node, c_ast.Enumerator):
        print("Enumerator: DODAJ AKCIJE")
        # Enumerator[name, values*]
        # A name/value pair for enumeration values
        
        
        
        
    elif isinstance (node, c_ast.EnumeratorList):
        print("Enumerator list")
        # EnumeratorList[enumerators**]
        # A list of enumerators
        
        if node.enumerators:
            for enumerator in node.enumerators:
                traverse(enumerator)
        
    elif isinstance (node, c_ast.ExprList):
        print("Expr list")
        # ExprList[exprs**]
        # izrazi razdvojeni zarezom
        
        if node.exprs:
            l = len(node.exprs)
            for expr in node.exprs:
                traverse(expr)
        
    elif isinstance (node, c_ast.For):
        print("For")
        # for (init; cond; next) stmt
        # For: [init*, cond*, next*, stmt*]
        # () se ne racuna
        
        if "for" in operators:
            operators["for"] += 1
        else:
            operators["for"] = 1  
        
        if node.init:
            traverse(node.init)
        if node.cond:
            traverse(node.cond)
        if node.next:
            traverse(node.next)
        if node.stmt:
            traverse(node.stmt)
        
    elif isinstance (node, c_ast.FuncCall):
        print("Func call")
        # FuncCall[name*, args*]
        # name: Id
        # args: ExprList
        # postoji nacin da se prebroje svi pozivi funkcija pa mozda ne mora ovde
        
        func_call = 1
        
        if node.name:
            traverse(node.name)
        if node.args:
            traverse(node.args)
        
        # ne treba zaboraviti na zagrade ( i )
        
    elif isinstance (node, c_ast.FuncDecl):
        print("Func decl") 
        
        func_decl = True
        
        # FuncDecl[args*, type*]
        if node.args:
            traverse(node.args)
        if node.type:
            traverse(node.type)
        
    elif isinstance (node, c_ast.FuncDef):
        print("FuncDef")
        # FuncDef [decl*, param_decls**, body*]
        node.decl.show(attrnames=True, nodenames=True)
        
        if node.decl:
            traverse(node.decl)
        if node.param_decls:
            for pd in node.param_decls:
                if pd:
                    traverse(pd)
        if node.body:
            traverse(node.body)
        
        # node.show(attrnames=True, nodenames=True)
        
        print('-----------------')
    elif isinstance (node, c_ast.Goto):
        print("goto")
        # Goto[name]
        # goto label;
        
        if "goto" in operators:
            operators["goto"] -= 1
        else:
            operators["goto"] = -1
        
        if node.name:
            if node.name in operators:
                operators[node.name] -= 1
            else:
                operators[node.name] = -1
        
    elif isinstance (node, c_ast.ID):
        print("ID")
        # ID[name]
        
        if assignment:
            print("assignment")
            if node.name in operands:
                operands[node.name] += 1
            else:
                operands[node.name] = 1
            assignment = 0
            return
        
        if is_return:
            print("return")
            if node.name in operands:
                operands[node.name] += 1
            else:
                operands[node.name] = 1
            is_return = 0
            return
        
        if array_ref:
            print("array_ref")
            if node.name in operands:
                operands[node.name] += 1
            else:
                operands[node.name] = 1
            array_ref = False
            return
        
        if func_call:
            print("func_call")
            if node.name in operators:
                operators[node.name] += 1
            else:
                operators[node.name] = 1
            func_call = 0
            return
        
        # nije deklaracija funkcije nego neka promenljiva
        if not func_decl:
            print("not func_decl")
            if node.name in operands:
                operands[node.name] += 1
            else:
                operands[node.name] = 1
            #func_call = 0
            return
        else:
            func_decl = False
            return

        
    elif isinstance (node, c_ast.IdentifierType):
        print("Identifier Type")
        # IdentifierType[names] [long long int]
        
        id_type = ""
        if node.names:
            for name in node.names:
                id_type += name
                id_type += ' '
        
        # ako postoje oba, prvo se razresava tpoint
        if tpoint and fpoint:
            print("tpoint i fpoint")
            for i in range(0, type_pointer):
                id_type += '*'
            print("id_type: "+id_type)
            type_pointer = 0
            tpoint = False
            if id_type in operands:
                operands[id_type] += 1
            else: 
                operands[id_type] = 1
            return
        
        elif tpoint:
            print("----> Usao u tpoint: ")
            for i in range(0, type_pointer):
                id_type += '*'
            print("id_type: "+id_type)
            type_pointer = 0
            tpoint = False
            if id_type in operands:
                operands[id_type] += 1
            else: 
                operands[id_type] = 1
            return

        elif fpoint:
            print("----> Usao u fpoint: ")
            for i in range(0, func_pointer):
                id_type += '*'
            print("id_type: "+id_type)
            func_pointer = 0
            fpoint = False
            if id_type in operands:
                operands[id_type] += 1
            else: 
                operands[id_type] = 1
            return
        
        else:
            if id_type in operands:
                operands[id_type] += 1
            else: 
                operands[id_type] = 1
            return
           
        #num_pointers = 0
        
    elif isinstance (node, c_ast.If):
        print("if")
        # If: [cond*, iftrue*, iffalse*]
        # if (cond*)
        # {
        #   iftrue*
        # }
        # iffalse* -> else {}
        
        if "if" in operators:
            operators["if"] += 1
        else:
            operators["if"] = 1  
                
        if node.cond:
            traverse(node.cond)
        if node.iftrue:
            traverse(node.iftrue)
        
        if node.iffalse:
            if "else" in operators:
                operators["else"] += 1
            else:
                operators["else"] = 1  
            
            traverse(node.iffalse)
        
    elif isinstance (node, c_ast.InitList):
        print("init list")
        # InitList: [exprs**]
        if node.exprs:
            for expr in node.exprs:
                traverse(expr)
        
        
    elif isinstance (node, c_ast.Label):
        print("label")
        # Label[name, stmt*]
        
        if node.stmt:
            traverse(node.stmt)
        
    elif isinstance (node, c_ast.NamedInitializer):
        print("Named Initializer ?")
        # NamedInitializer[name**, expr*]
        
        if node.name:
            for n in node.name:
                traverse(n)
        if node.expr:
            traverse(node.expr)        
        
    elif isinstance (node, c_ast.ParamList):
        print("Param list")
        # ParamList[params**]
                
        if node.params:
            num_params = len(node.params)
            for param in node.params:
                print(param)
                traverse(param)
        '''
        ParamList <args>: 
          Typename <params[0]>: name=None, quals=[]
            TypeDecl <type>: declname=None, quals=[]
              IdentifierType <type>: names=['void']
        '''
    elif isinstance (node, c_ast.Pragma):
        print("Pragma")
        # Pragma[string]
        
        if "pragma" in operators:
            operators["pragma"] += 1
        else:
            operators["pragma"] = 1
        
    elif isinstance (node, c_ast.PtrDecl):
        print("PtrDecl")
        # PtrDecl[quals, type*]
        
        # const, volatile
        quals = node.quals        
        if quals: # if true
            if (len(quals) == 2):
                #print(quals[0]+"   "+quals[1])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                if (quals[1] in operators):
                    operators[quals[1]] += 1
                else:
                    operators[quals[1]] = 1
            else: #(node.quals() == 1):
                #print(quals[0])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                    
        
        # num_pointers += 1
        
        if node.type:
            if isinstance (node.type, c_ast.TypeDecl) or isinstance (node.type, c_ast.PtrDecl):
                tpoint = True
                type_pointer += 1
            elif isinstance (node.type, c_ast.FuncDecl):
                fpoint = True
                func_pointer += 1                
            traverse(node.type)
        
    elif isinstance (node, c_ast.Return):
        print("Return")
        
        is_return = True
        # Return[expr*]
        if "return" in operators:
            operators["return"] += 1
        else:
            operators["return"] = 1
            
        if node.expr:
            traverse(node.expr)
        
    elif isinstance (node, c_ast.Struct):
        print("struct")                 
        # Struct[name, decls**]
        '''
            struct Books {
               char  title[50];
               char  author[50];
               char  subject[100];
               int   book_id;
            } book; 
        '''
        if "struct" in operators:
            operators["struct"] += 1
        else:
            operators["struct"] = 1
        # sa struct definisemo tip. ime tipa je operand
        # mozda ne treba da bude operand posto je deklaracija
        '''
        if node.name:
            if node.name in operands:
                operands[node.name] += 1
            else:
                operands[node.name] = 1
        '''        
        if node.name:
            id_type=""+node.name+" "
            if tpoint:
                # print("----> Usao u tpoint: ")
                for i in range(0, type_pointer):
                    id_type += '*'
                print("id_type: "+id_type)
                type_pointer = 0
                tpoint = False
                if id_type in operands:
                    operands[id_type] += 1
                else: 
                    operands[id_type] = 1
                return
                        
        if node.decls:
            for decl in node.decls:
                traverse(decl)
        
    elif isinstance (node, c_ast.StructRef):
        print("Struct ref")
        # type: . or ->
        # name.field or name->field
        # StructRef: [name*, type, field*]
        
        if node.type:
            if node.type in operators:
                operators[node.type] += 1
            else:
                operators[node.type] = 1 
            
        if node.name:
            traverse(node.name)
        if node.field:
            traverse(node.field)
        
    elif isinstance (node, c_ast.Switch):
        print("switch")
        # Switch[cond*, stmt*] 
        
        if "switch" in operators:
            operators["switch"] += 1
        else:
            operators["switch"] = 1  
                
        
        if node.cond:
            traverse(node.cond)
        if node.stmt:
            traverse(node.stmt)
        
    elif isinstance (node, c_ast.TernaryOp):
        print("ternary operator")
        # TernaryOperator[cond*, iftrue*, iffalse*]
        
        if "?:" in operators:
            operators["?:"] += 1
        else:
            operators["?:"] = 1 
        
        if node.cond:
            traverse(node.cond)
        if node.iftrue:
            traverse(node.iftrue)
        if node.iffalse:
            traverse(node.iffalse)
        
    elif isinstance (node, c_ast.TypeDecl):
        print("Type Decl")
        # TypeDecl[declname, quals, type*]
        
        # node.declname nije bitan jer je u pitanju deklaracija
        
               
        if num_params:
            if "None" not in str(node.declname):
                if node.declname in operands:
                    operands[node.declname] += 1
                else:
                    operands[node.declname] = 1
            num_params -= 1
        
        if node.type:
            traverse(node.type)
        
        '''
        # izgleda da nema potrebe da se i ovde nalazi jer se nalazi u Decl
        
        # const, volatile
        quals = node.quals        
        if quals: # if true
            if (len(quals) == 2):
                print(quals[0]+"   "+quals[1])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                if (quals[1] in operators):
                    operators[quals[1]] += 1
                else:
                    operators[quals[1]] = 1
            else: #(node.quals() == 1):
                #print("******************  "+node.quals[0])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
        '''
        

    elif isinstance (node, c_ast.Typedef):
        print("Typedef")
        # Typedef[name, quals, storage, type*]
        
        # neka promenljiva kao npr is_typedef ??
        
        # const, volatile
        quals = node.quals        
        if quals: # if true
            if (len(quals) == 2):
                #print(quals[0]+"   "+quals[1])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                if (quals[1] in operators):
                    operators[quals[1]] += 1
                else:
                    operators[quals[1]] = 1
            else: #(node.quals() == 1):
                #print(quals[0])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                
        # extern, register
        storage = node.storage        
        if storage: # if true
            if (len(storage) == 2):
                #print(storage[0]+"   "+storage[1])
                if (storage[0] in operators):
                    operators[storage[0]] += 1
                else:
                    operators[storage[0]] = 1
                if (storage[1] in operators):
                    operators[storage[1]] += 1
                else:
                    operators[storage[1]] = 1
            else: #(len(storage) == 1):
                #print(storage[0])
                if (storage[0] in operators):
                    operators[storage[0]] += 1
                else:
                    operators[storage[0]] = 1   
                    
        if node.type:
            traverse(node.type)
            
        # name ne bi trebalo da se racuna u deklaraciji
        
    elif isinstance (node, c_ast.Typename):
        print("Typename")
        # Typename[name, quals, type*]
        
        '''
        Typename <params[0]>: name=None, quals=[]
            TypeDecl <type>: declname=None, quals=[]
              IdentifierType <type>: names=['void']
        '''
        
               
        name = node.name
        if name:
            if name in operands:
                operands[name] += 1
            else:
                operands[name] = 1
        
        # const, volatile
        quals = node.quals        
        if quals: # if true
            if (len(quals) == 2):
                print(quals[0]+"   "+quals[1])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                if (quals[1] in operators):
                    operators[quals[1]] += 1
                else:
                    operators[quals[1]] = 1
            else: #(node.quals() == 1):
                #print("******************  "+node.quals[0])
                if (quals[0] in operators):
                    operators[quals[0]] += 1
                else:
                    operators[quals[0]] = 1
                    
        #print("**** "+str(type(node.type)))
        
              
        # !!! GRESKA
        if node.type:
        #    print("!!! "+str(type(node.type)))
            traverse(node.type)            
        
    elif isinstance (node, c_ast.UnaryOp):
        print("unary operator")
        # UnaryOperator[op, epxr*]
        
        if node.op:
            if node.op in operators:
                operators[node.op] += 1
            else:
                operators[node.op] = 1
                
        if node.expr:
            traverse(node.expr)
        
    elif isinstance (node, c_ast.Union):
        print("Union")  
        # Union[name, decls**]
        '''
        union Data {
           int i;
           float f;
           char str[20];
        };
        '''
        
        if "union" in operators:
            operators["union"] += 1
        else:
            operators["union"] = 1            
                
        # name ne bi trebalo da se racuna u deklaraciji
        
        if node.decls:
            for decl in node.decls:
                traverse(decl)
                
    elif isinstance (node, c_ast.While):
        print("while")     
        # While: [cond*, stmt*]
        
        if "while" in operators:
            operators["while"] += 1
        else:
            operators["while"] = 1            
        
        if node.cond:
            traverse(node.cond)
        if node.stmt:
            traverse(node.stmt)
        
    else:
        print("Error!")
        return 
    
    return

# %%
operators = {}
operands = {}
# broj pokazivaca za pointerdecl. anulira se u identifiertype
# num_pointers = 0
type_pointer = 0
tpoint = False
func_pointer = 0
fpoint = False
# ne zanima me ID ako je deklaracija, inace me zanima
# is_declaration = 0
# pozivi funkcija
func_call = 0
func_decl = False
assignment = False
is_return = False 
array_ref = False
num_params = 0

# %%
ast.show(attrnames=True, nodenames=True)
# Out:
# FileAST:
#   Typedef <ext[0]>: name=ReturnCode, quals=[], storage=['typedef']
#     TypeDecl <type>: declname=ReturnCode, quals=[]
#       Enum <type>: name=tagReturnCode
#         EnumeratorList <values>:
#           Enumerator <enumerators[0]>: name=SUCCESS
#           Enumerator <enumerators[1]>: name=FAIL
#   Typedef <ext[1]>: name=Entry, quals=[], storage=['typedef']
#     TypeDecl <type>: declname=Entry, quals=[]
#       Struct <type>: name=tagEntry
#         Decl <decls[0]>: name=key, quals=[], storage=[], funcspec=[]
#           PtrDecl <type>: quals=[]
#             TypeDecl <type>: declname=key, quals=[]
#               IdentifierType <type>: names=['char']
#         Decl <decls[1]>: name=value, quals=[], storage=[], funcspec=[]
#           PtrDecl <type>: quals=[]
#             TypeDecl <type>: declname=value, quals=[]
#               IdentifierType <type>: names=['char']
#   Typedef <ext[2]>: name=Node, quals=[], storage=['typedef']
#     TypeDecl <type>: declname=Node, quals=[]
#       Struct <type>: name=tagNode
#         Decl <decls[0]>: name=entry, quals=[], storage=[], funcspec=[]
#           PtrDecl <type>: quals=[]
#             TypeDecl <type>: declname=entry, quals=[]
#               IdentifierType <type>: names=['Entry']
#         Decl <decls[1]>: name=next, quals=[], storage=[], funcspec=[]
#           PtrDecl <type>: quals=[]
#             TypeDecl <type>: declname=next, quals=[]
#               Struct <type>: name=tagNode
#   Typedef <ext[3]>: name=Hash, quals=[], storage=['typedef']
#     TypeDecl <type>: declname=Hash, quals=[]
#       Struct <type>: name=tagHash
#         Decl <decls[0]>: name=table_size, quals=[], storage=[], funcspec=[]
#           TypeDecl <type>: declname=table_size, quals=[]
#             IdentifierType <type>: names=['unsigned', 'int']
#         Decl <decls[1]>: name=heads, quals=[], storage=[], funcspec=[]
#           PtrDecl <type>: quals=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=heads, quals=[]
#                 IdentifierType <type>: names=['Node']
#   FuncDef <ext[4]>:
#     Decl <decl>: name=hash_func, quals=[], storage=['static'], funcspec=[]
#       FuncDecl <type>:
#         ParamList <args>:
#           Decl <params[0]>: name=str, quals=['const'], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=str, quals=['const']
#                 IdentifierType <type>: names=['char']
#           Decl <params[1]>: name=table_size, quals=[], storage=[], funcspec=[]
#             TypeDecl <type>: declname=table_size, quals=[]
#               IdentifierType <type>: names=['unsigned', 'int']
#         TypeDecl <type>: declname=hash_func, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#     Compound <body>:
#       Decl <block_items[0]>: name=hash_value, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=hash_value, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#       Decl <block_items[1]>: name=a, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=a, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#         Constant <init>: type=int, value=127
#       For <block_items[2]>:
#         Assignment <init>: op==
#           ID <lvalue>: name=hash_value
#           Constant <rvalue>: type=int, value=0
#         BinaryOp <cond>: op=!=
#           UnaryOp <left>: op=*
#             ID <expr>: name=str
#           Constant <right>: type=int, value=0
#         UnaryOp <next>: op=++
#           ID <expr>: name=str
#         Assignment <stmt>: op==
#           ID <lvalue>: name=hash_value
#           BinaryOp <rvalue>: op=%
#             BinaryOp <left>: op=+
#               BinaryOp <left>: op=*
#                 ID <left>: name=a
#                 ID <right>: name=hash_value
#               UnaryOp <right>: op=*
#                 ID <expr>: name=str
#             ID <right>: name=table_size
#       Return <block_items[3]>:
#         ID <expr>: name=hash_value
#   FuncDef <ext[5]>:
#     Decl <decl>: name=HashCreate, quals=[], storage=[], funcspec=[]
#       FuncDecl <type>:
#         ParamList <args>:
#           Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               PtrDecl <type>: quals=[]
#                 TypeDecl <type>: declname=hash, quals=[]
#                   IdentifierType <type>: names=['Hash']
#           Decl <params[1]>: name=table_size, quals=[], storage=[], funcspec=[]
#             TypeDecl <type>: declname=table_size, quals=[]
#               IdentifierType <type>: names=['unsigned', 'int']
#         TypeDecl <type>: declname=HashCreate, quals=[]
#           IdentifierType <type>: names=['ReturnCode']
#     Compound <body>:
#       Decl <block_items[0]>: name=i, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=i, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#       If <block_items[1]>:
#         BinaryOp <cond>: op=<
#           ID <left>: name=table_size
#           Constant <right>: type=int, value=1
#         Return <iftrue>:
#           ID <expr>: name=FAIL
#       If <block_items[2]>:
#         BinaryOp <cond>: op===
#           Assignment <left>: op==
#             UnaryOp <lvalue>: op=*
#               ID <expr>: name=hash
#             FuncCall <rvalue>:
#               ID <name>: name=malloc
#               ExprList <args>:
#                 UnaryOp <exprs[0]>: op=sizeof
#                   UnaryOp <expr>: op=*
#                     UnaryOp <expr>: op=*
#                       ID <expr>: name=hash
#           ID <right>: name=NULL
#         Return <iftrue>:
#           ID <expr>: name=FAIL
#       If <block_items[3]>:
#         BinaryOp <cond>: op===
#           Assignment <left>: op==
#             StructRef <lvalue>: type=->
#               UnaryOp <name>: op=*
#                 ID <expr>: name=hash
#               ID <field>: name=heads
#             FuncCall <rvalue>:
#               ID <name>: name=malloc
#               ExprList <args>:
#                 BinaryOp <exprs[0]>: op=*
#                   ID <left>: name=table_size
#                   UnaryOp <right>: op=sizeof
#                     UnaryOp <expr>: op=*
#                       StructRef <expr>: type=->
#                         UnaryOp <name>: op=*
#                           ID <expr>: name=hash
#                         ID <field>: name=heads
#           ID <right>: name=NULL
#         Return <iftrue>:
#           ID <expr>: name=FAIL
#       For <block_items[4]>:
#         Assignment <init>: op==
#           ID <lvalue>: name=i
#           Constant <rvalue>: type=int, value=0
#         BinaryOp <cond>: op=<
#           ID <left>: name=i
#           ID <right>: name=table_size
#         UnaryOp <next>: op=++
#           ID <expr>: name=i
#         Compound <stmt>:
#           Assignment <block_items[0]>: op==
#             ArrayRef <lvalue>:
#               StructRef <name>: type=->
#                 UnaryOp <name>: op=*
#                   ID <expr>: name=hash
#                 ID <field>: name=heads
#               ID <subscript>: name=i
#             ID <rvalue>: name=NULL
#       Assignment <block_items[5]>: op==
#         StructRef <lvalue>: type=->
#           UnaryOp <name>: op=*
#             ID <expr>: name=hash
#           ID <field>: name=table_size
#         ID <rvalue>: name=table_size
#       Return <block_items[6]>:
#         ID <expr>: name=SUCCESS
#   FuncDef <ext[6]>:
#     Decl <decl>: name=HashInsert, quals=[], storage=[], funcspec=[]
#       FuncDecl <type>:
#         ParamList <args>:
#           Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=hash, quals=[]
#                 IdentifierType <type>: names=['Hash']
#           Decl <params[1]>: name=entry, quals=['const'], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=entry, quals=['const']
#                 IdentifierType <type>: names=['Entry']
#         TypeDecl <type>: declname=HashInsert, quals=[]
#           IdentifierType <type>: names=['ReturnCode']
#     Compound <body>:
#       Decl <block_items[0]>: name=index, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=index, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#         FuncCall <init>:
#           ID <name>: name=hash_func
#           ExprList <args>:
#             StructRef <exprs[0]>: type=->
#               ID <name>: name=entry
#               ID <field>: name=key
#             StructRef <exprs[1]>: type=->
#               ID <name>: name=hash
#               ID <field>: name=table_size
#       Decl <block_items[1]>: name=temp, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=temp, quals=[]
#             IdentifierType <type>: names=['Node']
#         ArrayRef <init>:
#           StructRef <name>: type=->
#             ID <name>: name=hash
#             ID <field>: name=heads
#           ID <subscript>: name=index
#       FuncCall <block_items[2]>:
#         ID <name>: name=HashRemove
#         ExprList <args>:
#           ID <exprs[0]>: name=hash
#           StructRef <exprs[1]>: type=->
#             ID <name>: name=entry
#             ID <field>: name=key
#       If <block_items[3]>:
#         BinaryOp <cond>: op===
#           Assignment <left>: op==
#             ArrayRef <lvalue>:
#               StructRef <name>: type=->
#                 ID <name>: name=hash
#                 ID <field>: name=heads
#               ID <subscript>: name=index
#             FuncCall <rvalue>:
#               ID <name>: name=malloc
#               ExprList <args>:
#                 UnaryOp <exprs[0]>: op=sizeof
#                   Typename <expr>: name=None, quals=[]
#                     TypeDecl <type>: declname=None, quals=[]
#                       IdentifierType <type>: names=['Node']
#           ID <right>: name=NULL
#         Return <iftrue>:
#           ID <expr>: name=FAIL
#       Assignment <block_items[4]>: op==
#         StructRef <lvalue>: type=->
#           ArrayRef <name>:
#             StructRef <name>: type=->
#               ID <name>: name=hash
#               ID <field>: name=heads
#             ID <subscript>: name=index
#           ID <field>: name=entry
#         FuncCall <rvalue>:
#           ID <name>: name=malloc
#           ExprList <args>:
#             UnaryOp <exprs[0]>: op=sizeof
#               Typename <expr>: name=None, quals=[]
#                 TypeDecl <type>: declname=None, quals=[]
#                   IdentifierType <type>: names=['Entry']
#       Assignment <block_items[5]>: op==
#         StructRef <lvalue>: type=->
#           StructRef <name>: type=->
#             ArrayRef <name>:
#               StructRef <name>: type=->
#                 ID <name>: name=hash
#                 ID <field>: name=heads
#               ID <subscript>: name=index
#             ID <field>: name=entry
#           ID <field>: name=key
#         FuncCall <rvalue>:
#           ID <name>: name=malloc
#           ExprList <args>:
#             BinaryOp <exprs[0]>: op=+
#               FuncCall <left>:
#                 ID <name>: name=strlen
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     ID <name>: name=entry
#                     ID <field>: name=key
#               Constant <right>: type=int, value=1
#       Assignment <block_items[6]>: op==
#         StructRef <lvalue>: type=->
#           StructRef <name>: type=->
#             ArrayRef <name>:
#               StructRef <name>: type=->
#                 ID <name>: name=hash
#                 ID <field>: name=heads
#               ID <subscript>: name=index
#             ID <field>: name=entry
#           ID <field>: name=value
#         FuncCall <rvalue>:
#           ID <name>: name=malloc
#           ExprList <args>:
#             BinaryOp <exprs[0]>: op=+
#               FuncCall <left>:
#                 ID <name>: name=strlen
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     ID <name>: name=entry
#                     ID <field>: name=value
#               Constant <right>: type=int, value=1
#       FuncCall <block_items[7]>:
#         ID <name>: name=strcpy
#         ExprList <args>:
#           StructRef <exprs[0]>: type=->
#             StructRef <name>: type=->
#               ArrayRef <name>:
#                 StructRef <name>: type=->
#                   ID <name>: name=hash
#                   ID <field>: name=heads
#                 ID <subscript>: name=index
#               ID <field>: name=entry
#             ID <field>: name=key
#           StructRef <exprs[1]>: type=->
#             ID <name>: name=entry
#             ID <field>: name=key
#       FuncCall <block_items[8]>:
#         ID <name>: name=strcpy
#         ExprList <args>:
#           StructRef <exprs[0]>: type=->
#             StructRef <name>: type=->
#               ArrayRef <name>:
#                 StructRef <name>: type=->
#                   ID <name>: name=hash
#                   ID <field>: name=heads
#                 ID <subscript>: name=index
#               ID <field>: name=entry
#             ID <field>: name=value
#           StructRef <exprs[1]>: type=->
#             ID <name>: name=entry
#             ID <field>: name=value
#       Assignment <block_items[9]>: op==
#         StructRef <lvalue>: type=->
#           ArrayRef <name>:
#             StructRef <name>: type=->
#               ID <name>: name=hash
#               ID <field>: name=heads
#             ID <subscript>: name=index
#           ID <field>: name=next
#         ID <rvalue>: name=temp
#       Return <block_items[10]>:
#         ID <expr>: name=SUCCESS
#   FuncDef <ext[7]>:
#     Decl <decl>: name=HashFind, quals=['const'], storage=[], funcspec=[]
#       FuncDecl <type>:
#         ParamList <args>:
#           Decl <params[0]>: name=hash, quals=['const'], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=hash, quals=['const']
#                 IdentifierType <type>: names=['Hash']
#           Decl <params[1]>: name=key, quals=['const'], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=key, quals=['const']
#                 IdentifierType <type>: names=['char']
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=HashFind, quals=['const']
#             IdentifierType <type>: names=['Entry']
#     Compound <body>:
#       Decl <block_items[0]>: name=index, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=index, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#         FuncCall <init>:
#           ID <name>: name=hash_func
#           ExprList <args>:
#             ID <exprs[0]>: name=key
#             StructRef <exprs[1]>: type=->
#               ID <name>: name=hash
#               ID <field>: name=table_size
#       Decl <block_items[1]>: name=temp, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=temp, quals=[]
#             IdentifierType <type>: names=['Node']
#         ArrayRef <init>:
#           StructRef <name>: type=->
#             ID <name>: name=hash
#             ID <field>: name=heads
#           ID <subscript>: name=index
#       While <block_items[2]>:
#         BinaryOp <cond>: op=!=
#           ID <left>: name=temp
#           ID <right>: name=NULL
#         Compound <stmt>:
#           If <block_items[0]>:
#             UnaryOp <cond>: op=!
#               FuncCall <expr>:
#                 ID <name>: name=strcmp
#                 ExprList <args>:
#                   ID <exprs[0]>: name=key
#                   StructRef <exprs[1]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp
#                       ID <field>: name=entry
#                     ID <field>: name=key
#             Return <iftrue>:
#               StructRef <expr>: type=->
#                 ID <name>: name=temp
#                 ID <field>: name=entry
#           Assignment <block_items[1]>: op==
#             ID <lvalue>: name=temp
#             StructRef <rvalue>: type=->
#               ID <name>: name=temp
#               ID <field>: name=next
#       Return <block_items[3]>:
#         ID <expr>: name=NULL
#   FuncDef <ext[8]>:
#     Decl <decl>: name=HashRemove, quals=[], storage=[], funcspec=[]
#       FuncDecl <type>:
#         ParamList <args>:
#           Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=hash, quals=[]
#                 IdentifierType <type>: names=['Hash']
#           Decl <params[1]>: name=key, quals=['const'], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=key, quals=['const']
#                 IdentifierType <type>: names=['char']
#         TypeDecl <type>: declname=HashRemove, quals=[]
#           IdentifierType <type>: names=['ReturnCode']
#     Compound <body>:
#       Decl <block_items[0]>: name=index, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=index, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#         FuncCall <init>:
#           ID <name>: name=hash_func
#           ExprList <args>:
#             ID <exprs[0]>: name=key
#             StructRef <exprs[1]>: type=->
#               ID <name>: name=hash
#               ID <field>: name=table_size
#       Decl <block_items[1]>: name=temp1, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=temp1, quals=[]
#             IdentifierType <type>: names=['Node']
#         ArrayRef <init>:
#           StructRef <name>: type=->
#             ID <name>: name=hash
#             ID <field>: name=heads
#           ID <subscript>: name=index
#       Decl <block_items[2]>: name=temp2, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=temp2, quals=[]
#             IdentifierType <type>: names=['Node']
#         ID <init>: name=temp1
#       While <block_items[3]>:
#         BinaryOp <cond>: op=!=
#           ID <left>: name=temp1
#           ID <right>: name=NULL
#         Compound <stmt>:
#           If <block_items[0]>:
#             UnaryOp <cond>: op=!
#               FuncCall <expr>:
#                 ID <name>: name=strcmp
#                 ExprList <args>:
#                   ID <exprs[0]>: name=key
#                   StructRef <exprs[1]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp1
#                       ID <field>: name=entry
#                     ID <field>: name=key
#             Compound <iftrue>:
#               If <block_items[0]>:
#                 BinaryOp <cond>: op===
#                   ID <left>: name=temp1
#                   ArrayRef <right>:
#                     StructRef <name>: type=->
#                       ID <name>: name=hash
#                       ID <field>: name=heads
#                     ID <subscript>: name=index
#                 Assignment <iftrue>: op==
#                   ArrayRef <lvalue>:
#                     StructRef <name>: type=->
#                       ID <name>: name=hash
#                       ID <field>: name=heads
#                     ID <subscript>: name=index
#                   StructRef <rvalue>: type=->
#                     ArrayRef <name>:
#                       StructRef <name>: type=->
#                         ID <name>: name=hash
#                         ID <field>: name=heads
#                       ID <subscript>: name=index
#                     ID <field>: name=next
#                 Assignment <iffalse>: op==
#                   StructRef <lvalue>: type=->
#                     ID <name>: name=temp2
#                     ID <field>: name=next
#                   StructRef <rvalue>: type=->
#                     ID <name>: name=temp1
#                     ID <field>: name=next
#               FuncCall <block_items[1]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp1
#                       ID <field>: name=entry
#                     ID <field>: name=key
#               FuncCall <block_items[2]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp1
#                       ID <field>: name=entry
#                     ID <field>: name=value
#               FuncCall <block_items[3]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     ID <name>: name=temp1
#                     ID <field>: name=entry
#               FuncCall <block_items[4]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   ID <exprs[0]>: name=temp1
#               Assignment <block_items[5]>: op==
#                 ID <lvalue>: name=temp1
#                 ID <rvalue>: name=NULL
#               Return <block_items[6]>:
#                 ID <expr>: name=SUCCESS
#           Assignment <block_items[1]>: op==
#             ID <lvalue>: name=temp2
#             ID <rvalue>: name=temp1
#           Assignment <block_items[2]>: op==
#             ID <lvalue>: name=temp1
#             StructRef <rvalue>: type=->
#               ID <name>: name=temp1
#               ID <field>: name=next
#       Return <block_items[4]>:
#         ID <expr>: name=FAIL
#   FuncDef <ext[9]>:
#     Decl <decl>: name=HashPrint, quals=[], storage=[], funcspec=[]
#       FuncDecl <type>:
#         ParamList <args>:
#           Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=hash, quals=[]
#                 IdentifierType <type>: names=['Hash']
#           Decl <params[1]>: name=PrintFunc, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               FuncDecl <type>:
#                 ParamList <args>:
#                   Typename <params[0]>: name=None, quals=[]
#                     PtrDecl <type>: quals=[]
#                       TypeDecl <type>: declname=None, quals=[]
#                         IdentifierType <type>: names=['char']
#                   Typename <params[1]>: name=None, quals=[]
#                     PtrDecl <type>: quals=[]
#                       TypeDecl <type>: declname=None, quals=[]
#                         IdentifierType <type>: names=['char']
#                 TypeDecl <type>: declname=PrintFunc, quals=[]
#                   IdentifierType <type>: names=['void']
#         TypeDecl <type>: declname=HashPrint, quals=[]
#           IdentifierType <type>: names=['void']
#     Compound <body>:
#       Decl <block_items[0]>: name=i, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=i, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#       If <block_items[1]>:
#         BinaryOp <cond>: op=||
#           BinaryOp <left>: op===
#             ID <left>: name=hash
#             ID <right>: name=NULL
#           BinaryOp <right>: op===
#             StructRef <left>: type=->
#               ID <name>: name=hash
#               ID <field>: name=heads
#             ID <right>: name=NULL
#         Return <iftrue>:
#       For <block_items[2]>:
#         Assignment <init>: op==
#           ID <lvalue>: name=i
#           Constant <rvalue>: type=int, value=0
#         BinaryOp <cond>: op=<
#           ID <left>: name=i
#           StructRef <right>: type=->
#             ID <name>: name=hash
#             ID <field>: name=table_size
#         UnaryOp <next>: op=++
#           ID <expr>: name=i
#         Compound <stmt>:
#           Decl <block_items[0]>: name=temp, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=temp, quals=[]
#                 IdentifierType <type>: names=['Node']
#             ArrayRef <init>:
#               StructRef <name>: type=->
#                 ID <name>: name=hash
#                 ID <field>: name=heads
#               ID <subscript>: name=i
#           While <block_items[1]>:
#             BinaryOp <cond>: op=!=
#               ID <left>: name=temp
#               ID <right>: name=NULL
#             Compound <stmt>:
#               FuncCall <block_items[0]>:
#                 ID <name>: name=PrintFunc
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp
#                       ID <field>: name=entry
#                     ID <field>: name=key
#                   StructRef <exprs[1]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp
#                       ID <field>: name=entry
#                     ID <field>: name=value
#               Assignment <block_items[1]>: op==
#                 ID <lvalue>: name=temp
#                 StructRef <rvalue>: type=->
#                   ID <name>: name=temp
#                   ID <field>: name=next
#   FuncDef <ext[10]>:
#     Decl <decl>: name=HashDestroy, quals=[], storage=[], funcspec=[]
#       FuncDecl <type>:
#         ParamList <args>:
#           Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=hash, quals=[]
#                 IdentifierType <type>: names=['Hash']
#         TypeDecl <type>: declname=HashDestroy, quals=[]
#           IdentifierType <type>: names=['void']
#     Compound <body>:
#       Decl <block_items[0]>: name=i, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=i, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#       If <block_items[1]>:
#         BinaryOp <cond>: op===
#           ID <left>: name=hash
#           ID <right>: name=NULL
#         Return <iftrue>:
#       For <block_items[2]>:
#         Assignment <init>: op==
#           ID <lvalue>: name=i
#           Constant <rvalue>: type=int, value=0
#         BinaryOp <cond>: op=<
#           ID <left>: name=i
#           StructRef <right>: type=->
#             ID <name>: name=hash
#             ID <field>: name=table_size
#         UnaryOp <next>: op=++
#           ID <expr>: name=i
#         Compound <stmt>:
#           Decl <block_items[0]>: name=temp, quals=[], storage=[], funcspec=[]
#             PtrDecl <type>: quals=[]
#               TypeDecl <type>: declname=temp, quals=[]
#                 IdentifierType <type>: names=['Node']
#             ArrayRef <init>:
#               StructRef <name>: type=->
#                 ID <name>: name=hash
#                 ID <field>: name=heads
#               ID <subscript>: name=i
#           While <block_items[1]>:
#             BinaryOp <cond>: op=!=
#               ID <left>: name=temp
#               ID <right>: name=NULL
#             Compound <stmt>:
#               Decl <block_items[0]>: name=temp2, quals=[], storage=[], funcspec=[]
#                 PtrDecl <type>: quals=[]
#                   TypeDecl <type>: declname=temp2, quals=[]
#                     IdentifierType <type>: names=['Node']
#                 ID <init>: name=temp
#               FuncCall <block_items[1]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp
#                       ID <field>: name=entry
#                     ID <field>: name=key
#               FuncCall <block_items[2]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     StructRef <name>: type=->
#                       ID <name>: name=temp
#                       ID <field>: name=entry
#                     ID <field>: name=value
#               FuncCall <block_items[3]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   StructRef <exprs[0]>: type=->
#                     ID <name>: name=temp
#                     ID <field>: name=entry
#               Assignment <block_items[4]>: op==
#                 ID <lvalue>: name=temp
#                 StructRef <rvalue>: type=->
#                   ID <name>: name=temp
#                   ID <field>: name=next
#               FuncCall <block_items[5]>:
#                 ID <name>: name=free
#                 ExprList <args>:
#                   ID <exprs[0]>: name=temp2
#       FuncCall <block_items[3]>:
#         ID <name>: name=free
#         ExprList <args>:
#           StructRef <exprs[0]>: type=->
#             ID <name>: name=hash
#             ID <field>: name=heads
#       Assignment <block_items[4]>: op==
#         StructRef <lvalue>: type=->
#           ID <name>: name=hash
#           ID <field>: name=heads
#         ID <rvalue>: name=NULL
#       FuncCall <block_items[5]>:
#         ID <name>: name=free
#         ExprList <args>:
#           ID <exprs[0]>: name=hash

# %%
# FileAst[ext**]
for node in ast.ext:
    print(node)
    traverse(node)
# Out:
# <pycparser.c_ast.Typedef object at 0x7fda503b2f10>
# Typedef
# Type Decl
# enum
# Enumerator list
# Enumerator: DODAJ AKCIJE
# Enumerator: DODAJ AKCIJE
# <pycparser.c_ast.Typedef object at 0x7fda503b2518>
# Typedef
# Type Decl
# struct
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: char *
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: char *
# <pycparser.c_ast.Typedef object at 0x7fda503b2fc0>
# Typedef
# Type Decl
# struct
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Entry *
# Decl
# PtrDecl
# Type Decl
# struct
# id_type: tagNode *
# <pycparser.c_ast.Typedef object at 0x7fda50197ba0>
# Typedef
# Type Decl
# struct
# Decl
# Type Decl
# Identifier Type
# Decl
# PtrDecl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node **
# <pycparser.c_ast.FuncDef object at 0x7fda5019f228>
# FuncDef
# Decl: name=hash_func, quals=[], storage=['static'], funcspec=[]
#   FuncDecl <type>:
#     ParamList <args>:
#       Decl <params[0]>: name=str, quals=['const'], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=str, quals=['const']
#             IdentifierType <type>: names=['char']
#       Decl <params[1]>: name=table_size, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=table_size, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#     TypeDecl <type>: declname=hash_func, quals=[]
#       IdentifierType <type>: names=['unsigned', 'int']
# Decl
# Func decl
# Param list
# <pycparser.c_ast.Decl object at 0x7fda50096668>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: char *
# <pycparser.c_ast.Decl object at 0x7fda500966d8>
# Decl
# Type Decl
# Identifier Type
# Type Decl
# Identifier Type
# Compound
# Decl
# Type Decl
# Identifier Type
# Decl
# Type Decl
# Identifier Type
# Constant
# For
# Assignment
# ID
# assignment
# Constant
# Binary op
# unary operator
# ID
# Constant
# unary operator
# ID
# not func_decl
# Assignment
# ID
# assignment
# Binary op
# Binary op
# Binary op
# ID
# not func_decl
# ID
# not func_decl
# unary operator
# ID
# not func_decl
# ID
# not func_decl
# Return
# ID
# return
# -----------------
# <pycparser.c_ast.FuncDef object at 0x7fda5019f868>
# FuncDef
# Decl: name=HashCreate, quals=[], storage=[], funcspec=[]
#   FuncDecl <type>:
#     ParamList <args>:
#       Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           PtrDecl <type>: quals=[]
#             TypeDecl <type>: declname=hash, quals=[]
#               IdentifierType <type>: names=['Hash']
#       Decl <params[1]>: name=table_size, quals=[], storage=[], funcspec=[]
#         TypeDecl <type>: declname=table_size, quals=[]
#           IdentifierType <type>: names=['unsigned', 'int']
#     TypeDecl <type>: declname=HashCreate, quals=[]
#       IdentifierType <type>: names=['ReturnCode']
# Decl
# Func decl
# Param list
# <pycparser.c_ast.Decl object at 0x7fda50096898>
# Decl
# PtrDecl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Hash **
# <pycparser.c_ast.Decl object at 0x7fda50096908>
# Decl
# Type Decl
# Identifier Type
# Type Decl
# Identifier Type
# Compound
# Decl
# Type Decl
# Identifier Type
# if
# Binary op
# ID
# Constant
# Return
# ID
# return
# if
# Binary op
# Assignment
# unary operator
# ID
# assignment
# Func call
# ID
# func_call
# Expr list
# unary operator
# unary operator
# unary operator
# ID
# not func_decl
# ID
# not func_decl
# Return
# ID
# return
# if
# Binary op
# Assignment
# Struct ref
# unary operator
# ID
# assignment
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Binary op
# ID
# not func_decl
# unary operator
# unary operator
# Struct ref
# unary operator
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Return
# ID
# return
# For
# Assignment
# ID
# assignment
# Constant
# Binary op
# ID
# not func_decl
# ID
# not func_decl
# unary operator
# ID
# not func_decl
# Compound
# Assignment
# ArrayRef
# Struct ref
# unary operator
# ID
# assignment
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# Assignment
# Struct ref
# unary operator
# ID
# assignment
# ID
# not func_decl
# ID
# not func_decl
# Return
# ID
# return
# -----------------
# <pycparser.c_ast.FuncDef object at 0x7fda501b85e8>
# FuncDef
# Decl: name=HashInsert, quals=[], storage=[], funcspec=[]
#   FuncDecl <type>:
#     ParamList <args>:
#       Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=hash, quals=[]
#             IdentifierType <type>: names=['Hash']
#       Decl <params[1]>: name=entry, quals=['const'], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=entry, quals=['const']
#             IdentifierType <type>: names=['Entry']
#     TypeDecl <type>: declname=HashInsert, quals=[]
#       IdentifierType <type>: names=['ReturnCode']
# Decl
# Func decl
# Param list
# <pycparser.c_ast.Decl object at 0x7fda50096a58>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Hash *
# <pycparser.c_ast.Decl object at 0x7fda50096cf8>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Entry *
# Type Decl
# Identifier Type
# Compound
# Decl
# Type Decl
# Identifier Type
# Func call
# ID
# func_call
# Expr list
# Struct ref
# ID
# ID
# not func_decl
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node *
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# ID
# not func_decl
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# if
# Binary op
# Assignment
# ArrayRef
# Struct ref
# ID
# assignment
# ID
# array_ref
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# unary operator
# Typename
# Type Decl
# Identifier Type
# ID
# not func_decl
# Return
# ID
# return
# Assignment
# Struct ref
# ArrayRef
# Struct ref
# ID
# assignment
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# unary operator
# Typename
# Type Decl
# Identifier Type
# Assignment
# Struct ref
# Struct ref
# ArrayRef
# Struct ref
# ID
# assignment
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Binary op
# Func call
# ID
# func_call
# Expr list
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Constant
# Assignment
# Struct ref
# Struct ref
# ArrayRef
# Struct ref
# ID
# assignment
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Binary op
# Func call
# ID
# func_call
# Expr list
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Constant
# Func call
# ID
# func_call
# Expr list
# Struct ref
# Struct ref
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# Struct ref
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Assignment
# Struct ref
# ArrayRef
# Struct ref
# ID
# assignment
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Return
# ID
# return
# -----------------
# <pycparser.c_ast.FuncDef object at 0x7fda501b8b88>
# FuncDef
# Decl: name=HashFind, quals=['const'], storage=[], funcspec=[]
#   FuncDecl <type>:
#     ParamList <args>:
#       Decl <params[0]>: name=hash, quals=['const'], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=hash, quals=['const']
#             IdentifierType <type>: names=['Hash']
#       Decl <params[1]>: name=key, quals=['const'], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=key, quals=['const']
#             IdentifierType <type>: names=['char']
#     PtrDecl <type>: quals=[]
#       TypeDecl <type>: declname=HashFind, quals=['const']
#         IdentifierType <type>: names=['Entry']
# Decl
# Func decl
# Param list
# <pycparser.c_ast.Decl object at 0x7fda50096c88>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Hash *
# <pycparser.c_ast.Decl object at 0x7fda50096f28>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: char *
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Entry *
# Compound
# Decl
# Type Decl
# Identifier Type
# Func call
# ID
# func_call
# Expr list
# ID
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node *
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# while
# Binary op
# ID
# not func_decl
# ID
# not func_decl
# Compound
# if
# unary operator
# Func call
# ID
# func_call
# Expr list
# ID
# not func_decl
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Return
# Struct ref
# ID
# return
# ID
# not func_decl
# Assignment
# ID
# assignment
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Return
# ID
# return
# -----------------
# <pycparser.c_ast.FuncDef object at 0x7fda501c75e8>
# FuncDef
# Decl: name=HashRemove, quals=[], storage=[], funcspec=[]
#   FuncDecl <type>:
#     ParamList <args>:
#       Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=hash, quals=[]
#             IdentifierType <type>: names=['Hash']
#       Decl <params[1]>: name=key, quals=['const'], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=key, quals=['const']
#             IdentifierType <type>: names=['char']
#     TypeDecl <type>: declname=HashRemove, quals=[]
#       IdentifierType <type>: names=['ReturnCode']
# Decl
# Func decl
# Param list
# <pycparser.c_ast.Decl object at 0x7fda50096eb8>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Hash *
# <pycparser.c_ast.Decl object at 0x7fda50227e48>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: char *
# Type Decl
# Identifier Type
# Compound
# Decl
# Type Decl
# Identifier Type
# Func call
# ID
# func_call
# Expr list
# ID
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node *
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node *
# ID
# not func_decl
# while
# Binary op
# ID
# not func_decl
# ID
# not func_decl
# Compound
# if
# unary operator
# Func call
# ID
# func_call
# Expr list
# ID
# not func_decl
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Compound
# if
# Binary op
# ID
# not func_decl
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# Assignment
# ArrayRef
# Struct ref
# ID
# assignment
# ID
# array_ref
# ID
# not func_decl
# Struct ref
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Assignment
# Struct ref
# ID
# assignment
# ID
# not func_decl
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# ID
# not func_decl
# Assignment
# ID
# assignment
# ID
# not func_decl
# Return
# ID
# return
# Assignment
# ID
# assignment
# ID
# not func_decl
# Assignment
# ID
# assignment
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Return
# ID
# return
# -----------------
# <pycparser.c_ast.FuncDef object at 0x7fda501c7e58>
# FuncDef
# Decl: name=HashPrint, quals=[], storage=[], funcspec=[]
#   FuncDecl <type>:
#     ParamList <args>:
#       Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=hash, quals=[]
#             IdentifierType <type>: names=['Hash']
#       Decl <params[1]>: name=PrintFunc, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           FuncDecl <type>:
#             ParamList <args>:
#               Typename <params[0]>: name=None, quals=[]
#                 PtrDecl <type>: quals=[]
#                   TypeDecl <type>: declname=None, quals=[]
#                     IdentifierType <type>: names=['char']
#               Typename <params[1]>: name=None, quals=[]
#                 PtrDecl <type>: quals=[]
#                   TypeDecl <type>: declname=None, quals=[]
#                     IdentifierType <type>: names=['char']
#             TypeDecl <type>: declname=PrintFunc, quals=[]
#               IdentifierType <type>: names=['void']
#     TypeDecl <type>: declname=HashPrint, quals=[]
#       IdentifierType <type>: names=['void']
# Decl
# Func decl
# Param list
# <pycparser.c_ast.Decl object at 0x7fda50227748>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Hash *
# <pycparser.c_ast.Decl object at 0x7fda500dcb38>
# Decl
# PtrDecl
# Func decl
# Param list
# <pycparser.c_ast.Typename object at 0x7fda501c7778>
# Typename
# PtrDecl
# Type Decl
# Identifier Type
# tpoint i fpoint
# id_type: char *
# <pycparser.c_ast.Typename object at 0x7fda501c7818>
# Typename
# PtrDecl
# Type Decl
# Identifier Type
# tpoint i fpoint
# id_type: char *
# Type Decl
# Identifier Type
# ----> Usao u fpoint:
# id_type: void *
# Type Decl
# Identifier Type
# Compound
# Decl
# Type Decl
# Identifier Type
# if
# Binary op
# Binary op
# ID
# ID
# not func_decl
# Binary op
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Return
# For
# Assignment
# ID
# assignment
# Constant
# Binary op
# ID
# return
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# unary operator
# ID
# not func_decl
# Compound
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node *
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# while
# Binary op
# ID
# not func_decl
# ID
# not func_decl
# Compound
# Func call
# ID
# func_call
# Expr list
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Assignment
# ID
# assignment
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# -----------------
# <pycparser.c_ast.FuncDef object at 0x7fda5024f548>
# FuncDef
# Decl: name=HashDestroy, quals=[], storage=[], funcspec=[]
#   FuncDecl <type>:
#     ParamList <args>:
#       Decl <params[0]>: name=hash, quals=[], storage=[], funcspec=[]
#         PtrDecl <type>: quals=[]
#           TypeDecl <type>: declname=hash, quals=[]
#             IdentifierType <type>: names=['Hash']
#     TypeDecl <type>: declname=HashDestroy, quals=[]
#       IdentifierType <type>: names=['void']
# Decl
# Func decl
# Param list
# <pycparser.c_ast.Decl object at 0x7fda500dc518>
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Hash *
# Type Decl
# Identifier Type
# Compound
# Decl
# Type Decl
# Identifier Type
# if
# Binary op
# ID
# ID
# not func_decl
# Return
# For
# Assignment
# ID
# assignment
# Constant
# Binary op
# ID
# return
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# unary operator
# ID
# not func_decl
# Compound
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node *
# ArrayRef
# Struct ref
# ID
# array_ref
# ID
# not func_decl
# ID
# not func_decl
# while
# Binary op
# ID
# not func_decl
# ID
# not func_decl
# Compound
# Decl
# PtrDecl
# Type Decl
# Identifier Type
# ----> Usao u tpoint:
# id_type: Node *
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Assignment
# ID
# assignment
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# Struct ref
# ID
# not func_decl
# ID
# not func_decl
# Assignment
# Struct ref
# ID
# assignment
# ID
# not func_decl
# ID
# not func_decl
# Func call
# ID
# func_call
# Expr list
# ID
# not func_decl
# -----------------

# %%
print(operands)
print(operators)
# Out:
# {'char *': 7, 'Entry *': 3, 'tagNode *': 1, 'unsigned int ': 12, 'Node **': 1, 'str': 3, 'table_size': 12, 'hash_value': 4, 'a': 1, 'hash': 37, 'Hash **': 1, 'ReturnCode ': 3, 'FAIL': 5, 'NULL': 14, 'heads': 21, 'i': 12, 'SUCCESS': 3, 'Hash *': 5, 'entry': 22, 'key': 15, 'Node *': 7, 'index': 13, 'Node ': 1, 'Entry ': 1, 'value': 7, 'next': 8, 'temp': 18, 'temp1': 13, 'temp2': 3, 'void *': 1, 'void ': 2}
# {'typedef': 4, 'enum': 1, 'struct': 4, 'static': 1, 'const': 6, '=': 34, 'for': 4, '!=': 5, '*': 12, '++': 4, '%': 1, '+': 3, 'return': 13, 'if': 9, '<': 4, '==': 7, 'malloc': 6, 'sizeof': 4, '->': 69, 'hash_func': 3, 'HashRemove': 1, 'strlen': 2, 'strcpy': 2, 'while': 4, '!': 2, 'strcmp': 2, 'else': 1, 'free': 10, '||': 1, 'PrintFunc': 1}

# %%
# file = open("./pycparser-master/examples/c_files/funky.c")

file = open("./pycparser-master/examples/c_files/hash.c")

# %%
# file_string = file.read()

ff = file.readlines()

file.close()

# %%
# file_string

#ff

# %%
import re

# %%
# uklanjamo komentare                                 

file_string = ""
for f in ff:
    file_string += re.sub("(?:\/\/(?:\\\n|[^\n])*\n)|(?:\/\*[\s\S]*?\*\/)|((?:R\"([^(\\\s]{0,16})\([^)]*\)\2\")|(?:@\"[^\"]*?\")|(?:\"(?:\?\?'|\\\\|\\\"|\\\n|[^\"])*?\")|(?:'(?:\\\\|\\'|\\\n|[^'])*?'))", '', f)
#print(file_string)

# num = re.subn("(?:\/\/(?:\\\n|[^\n])*\n)|(?:\/\*[\s\S]*?\*\/)|((?:R\"([^(\\\s]{0,16})\([^)]*\)\2\")|(?:@\"[^\"]*?\")|(?:\"(?:\?\?'|\\\\|\\\"|\\\n|[^\"])*?\")|(?:'(?:\\\\|\\'|\\\n|[^'])*?'))", '', file_string)[1]
# print(str(num))

# %%
file_string = re.sub("(?:\/\/(?:\\\n|[^\n])*\n)|(?:\/\*[\s\S]*?\*\/)|((?:R\"([^(\\\s]{0,16})\([^)]*\)\2\")|(?:@\"[^\"]*?\")|(?:\"(?:\?\?'|\\\\|\\\"|\\\n|[^\"])*?\")|(?:'(?:\\\\|\\'|\\\n|[^'])*?'))", '', file_string)
print(file_string)
# Out:
# typedef enum tagReturnCode {SUCCESS, FAIL} ReturnCode;
#
#
# typedef struct tagEntry
# {
#     char* key;
#     char* value;
# } Entry;
#
#
#
# typedef struct tagNode
# {
#     Entry* entry;
#
#     struct tagNode* next;
# } Node;
#
#
# typedef struct tagHash
# {
#     unsigned int table_size;
#
#     Node** heads;
#
# } Hash;
#
#
# static unsigned int hash_func(const char* str, unsigned int table_size)
# {
#     unsigned int hash_value;
#     unsigned int a = 127;
#
#     for (hash_value = 0; *str != 0; ++str)
#         hash_value = (a*hash_value + *str) % table_size;
#
#     return hash_value;
# }
#
#
# ReturnCode HashCreate(Hash** hash, unsigned int table_size)
# {
#     unsigned int i;
#
#     if (table_size < 1)
#         return FAIL;
#
#                 if (((*hash) = malloc(sizeof(**hash))) == NULL)
#         return FAIL;
#
#                 if (((*hash)->heads = malloc(table_size*sizeof(*((*hash)->heads)))) == NULL)
#         return FAIL;
#
#                 for (i = 0; i < table_size; ++i)
#     {
#         (*hash)->heads[i] = NULL;
#     }
#
#     (*hash)->table_size = table_size;
#
#     return SUCCESS;
# }
#
#
# ReturnCode HashInsert(Hash* hash, const Entry* entry)
# {
#     unsigned int index = hash_func(entry->key, hash->table_size);
#     Node* temp = hash->heads[index];
#
#     HashRemove(hash, entry->key);
#
#     if ((hash->heads[index] = malloc(sizeof(Node))) == NULL)
#         return FAIL;
#
#     hash->heads[index]->entry = malloc(sizeof(Entry));
#     hash->heads[index]->entry->key = malloc(strlen(entry->key)+1);
#     hash->heads[index]->entry->value = malloc(strlen(entry->value)+1);
#     strcpy(hash->heads[index]->entry->key, entry->key);
#     strcpy(hash->heads[index]->entry->value, entry->value);
#
#     hash->heads[index]->next = temp;
#
#     return SUCCESS;
# }
#
#
#
# const Entry* HashFind(const Hash* hash, const char* key)
# {
#     unsigned int index = hash_func(key, hash->table_size);
#     Node* temp = hash->heads[index];
#
#     while (temp != NULL)
#     {
#         if (!strcmp(key, temp->entry->key))
#             return temp->entry;
#
#         temp = temp->next;
#     }
#
#     return NULL;
# }
#
#
# ReturnCode HashRemove(Hash* hash, const char* key)
# {
#     unsigned int index = hash_func(key, hash->table_size);
#     Node* temp1 = hash->heads[index];
#     Node* temp2 = temp1;
#
#     while (temp1 != NULL)
#     {
#         if (!strcmp(key, temp1->entry->key))
#         {
#             if (temp1 == hash->heads[index])
#                 hash->heads[index] = hash->heads[index]->next;
#             else
#                 temp2->next = temp1->next;
#
#             free(temp1->entry->key);
#             free(temp1->entry->value);
#             free(temp1->entry);
#             free(temp1);
#             temp1 = NULL;
#
#             return SUCCESS;
#         }
#
#         temp2 = temp1;
#         temp1 = temp1->next;
#     }
#
#     return FAIL;
# }
#
#
# void HashPrint(Hash* hash, void (*PrintFunc)(char*, char*))
# {
#     unsigned int i;
#
#     if (hash == NULL || hash->heads == NULL)
#         return;
#
#     for (i = 0; i < hash->table_size; ++i)
#     {
#         Node* temp = hash->heads[i];
#
#         while (temp != NULL)
#         {
#             PrintFunc(temp->entry->key, temp->entry->value);
#             temp = temp->next;
#         }
#     }
# }
#
#
#
# void HashDestroy(Hash* hash)
# {
#     unsigned int i;
#
#     if (hash == NULL)
#         return;
#
#     for (i = 0; i < hash->table_size; ++i)
#     {
#         Node* temp = hash->heads[i];
#
#         while (temp != NULL)
#         {
#             Node* temp2 = temp;
#
#             free(temp->entry->key);
#             free(temp->entry->value);
#             free(temp->entry);
#
#             temp = temp->next;
#
#             free(temp2);
#         }
#     }
#
#     free(hash->heads);
#     hash->heads = NULL;
#
#     free(hash);
# }

# %%
global operators
global operands

# parentheses ()
parentheses_left = re.findall("\(", file_string)
parentheses_right = re.findall("\)", file_string)
print(str(len(parentheses_left)))

# broj () je broj zagrada umanjen za broj zagrada koje se nalaze uz for, if, ...
parentheses_to_deduct = 0
if "for" in operators.keys():
    parentheses_to_deduct += operators["for"]
if "if" in operators.keys():
    parentheses_to_deduct += operators["if"]    
if "while" in operators.keys():
    parentheses_to_deduct += operators["while"]
if "switch" in operators.keys():
    parentheses_to_deduct += operators["switch"]
    
print(parentheses_to_deduct)

operators['('] = len(parentheses_left) - parentheses_to_deduct
operators[')'] = len(parentheses_right) - parentheses_to_deduct

# braces {}
braces_left = re.findall("\{", file_string)
operators['{'] = len(braces_left)
braces_right = re.findall("\}", file_string)
operators['}'] = len(braces_right)

# brackets []
brackets_left = re.findall("\[", file_string)
if len(brackets_left):
    operators['['] = len(brackets_left)
    
brackets_right = re.findall("\]", file_string)
if len(brackets_right):
    operators[']'] = len(brackets_right)

# comma ,
comma = re.findall("\,", file_string)
if len(comma):
    operators[','] = len(comma)

# semicolon ;
semicolon = re.findall("\;", file_string)
if len(semicolon):
    operators[';'] = len(semicolon)

# colon :
colon = re.findall("\:", file_string)
if len(colon):
    operators[':'] = len(colon)
    
# apostrophe ;
apostrophe = re.findall("\'", file_string)
if len(apostrophe):
    operators['\''] = len(apostrophe)

# quotation :
quotation = re.findall("\"", file_string)
if len(quotation):
    operators['\"'] = len(quotation)    
    
# hashtag #;
hashtag = re.findall("\#", file_string)
if len(hashtag):
    operators['\#'] = len(hashtag)

# double_hashtag ## :
double_hashtag = re.findall("\#\#", file_string)
if len(double_hashtag):
    operators['\#\#'] = len(double_hashtag)

print("--> {operators} : "+str(operators)+'\n')
print("--> {operands} : "+str(operands))
# Out:
# 67
# 17
# --> {operators} : {'typedef': 4, 'enum': 1, 'struct': 4, 'static': 1, 'const': 6, '=': 34, 'for': 4, '!=': 5, '*': 12, '++': 4, '%': 1, '+': 3, 'return': 13, 'if': 9, '<': 4, '==': 7, 'malloc': 6, 'sizeof': 4, '->': 69, 'hash_func': 3, 'HashRemove': 1, 'strlen': 2, 'strcpy': 2, 'while': 4, '!': 2, 'strcmp': 2, 'else': 1, 'free': 10, '||': 1, 'PrintFunc': 1, '(': 50, ')': 50, '{': 19, '}': 19, '[': 16, ']': 16, ',': 17, ';': 76}
#
# --> {operands} : {'char *': 7, 'Entry *': 3, 'tagNode *': 1, 'unsigned int ': 12, 'Node **': 1, 'str': 3, 'table_size': 12, 'hash_value': 4, 'a': 1, 'hash': 37, 'Hash **': 1, 'ReturnCode ': 3, 'FAIL': 5, 'NULL': 14, 'heads': 21, 'i': 12, 'SUCCESS': 3, 'Hash *': 5, 'entry': 22, 'key': 15, 'Node *': 7, 'index': 13, 'Node ': 1, 'Entry ': 1, 'value': 7, 'next': 8, 'temp': 18, 'temp1': 13, 'temp2': 3, 'void *': 1, 'void ': 2}
